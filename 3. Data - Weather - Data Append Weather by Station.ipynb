# %%
import pandas as pd
import numpy as np

# %%
train_data_station1   = pd.read_csv('./train_station1.csv')
train_data_station2   = pd.read_csv('./train_Station2.csv')

test_data_station1   = pd.read_csv('./test_station1.csv')
test_data_station2   = pd.read_csv('./test_Station2.csv')

weather_data = pd.read_csv('./assets/weather.csv')

# %%
weather_data.shape
# Out:
# (2944, 22)

# %%
#maybe impute missing M instead?
weather_data.replace('M', 0, inplace=True)
weather_data.replace('T', 0, inplace=True)
weather_data.replace(' T', 0, inplace=True)
weather_data.replace('  T', 0, inplace=True)

# %%
#these have almost no data
#sunset/sunrise - not sure how these can contribute

weather_data.drop(columns=['Water1', 'SnowFall', 'Depth', 'Sunrise','Sunset'], axis=1, inplace=True)

# %%
#changing dtypes for some variables that are viewed as strings

weather_data['SeaLevel'] = weather_data['SeaLevel'].astype(float)
weather_data['AvgSpeed'] = weather_data['AvgSpeed'].astype(float)
weather_data['PrecipTotal'] = weather_data['PrecipTotal'].astype(float)
weather_data['StnPressure'] = weather_data['StnPressure'].astype(float)
weather_data['WetBulb'] = weather_data['WetBulb'].astype(int)
weather_data['Depart'] = weather_data['Depart'].astype(int)

# %%
#converting some more variables from strings to integers. For some reason the above approach
#did not work for these.

new =[]
for i in weather_data['Tavg']:
    new.append(int(i))
weather_data['Tavg'] = new

new =[]
for i in weather_data['Heat']:
    new.append(int(i))
weather_data['Heat'] = new

new =[]
for i in weather_data['Cool']:
    new.append(int(i))
weather_data['Cool'] = new

# %%
#see if changing precip into fewer categories would make a difference

new_precip = []
for i in weather_data['PrecipTotal']:
    if i == 0:
        new_precip.append('No_Precip')
    if i>0 and i<=1:
        new_precip.append('Trace')
    if i>1:
        new_precip.append('Precip')
weather_data['PrecipCat'] = new_precip

# %%
# Alternative handling of these weather patterns:
# (patterns present vs not) EXCEPT all the missing values count as 0

patterns = ['SH', 'DZ', 'RA', 'TS', 'BR']
string = 'SH'  
count = []
for i in weather_data['CodeSum']:
    if any(x in i for x in patterns):
        count.append(0)
    else:
        count.append(1)
len(count)
weather_data['NewCodeSum'] = count
weather_data['NewCodeSum'].value_counts()
# Out:
# 1    1651
# 0    1293
# Name: NewCodeSum, dtype: int64

# %%
# we only care about Shower(SH), drizzle(DZ), rain(RA)
# Thunderstorm(TS), Mist(BR) = Each of these will reduce the number of mosquitoes

#I THINK THIS MAY BE ONLY PICKING OBSERVATIONS WHERE WE SEE ONE OF THESE, NOT COMBINED. ASK BRIAN IF THAT WAS
#THE INTENT (if we have SH DZ - we don't want that?)


patterns = ['SH', 'DZ', 'RA', 'TS', 'BR']

# iterate through all the CodeSum to find the columns with the patterns list
weather_data['CodeSum'] = weather_data['CodeSum'].apply(lambda x: [t for t in x.split('0') 
                                                                   if t in patterns])
# converts everything from the lists that were created in the previous code into strings
weather_data['CodeSum'] = weather_data['CodeSum'].apply(lambda x: 
                                                x if not isinstance(x, list) else x[0] if len(x) else 'None')

weather_data.CodeSum.value_counts()
# Out:
# None    2520
# RA       296
# BR       110
# TS        10
# DZ         8
# Name: CodeSum, dtype: int64

# %%
weather_data.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg             int64
# Depart           int64
# DewPoint         int64
# WetBulb          int64
# Heat             int64
# Cool             int64
# CodeSum         object
# PrecipTotal    float64
# StnPressure    float64
# SeaLevel       float64
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed       float64
# PrecipCat       object
# NewCodeSum       int64
# dtype: object

# %%
weather_data.head()
# Out:
#    Station        Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 0        1  2007-05-01    83    50    67      14        51       56     0
# 1        2  2007-05-01    84    52    68       0        51       57     0
# 2        1  2007-05-02    59    42    51      -3        42       47    14
# 3        2  2007-05-02    60    43    52       0        42       47    13
# 4        1  2007-05-03    66    46    56       2        40       48     9
#
#    Cool CodeSum  PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  \
# 0     2    None          0.0        29.10     29.82          1.7         27
# 1     3    None          0.0        29.18     29.82          2.7         25
# 2     0      BR          0.0        29.38     30.09         13.0          4
# 3     0    None          0.0        29.44     30.08         13.3          2
# 4     0    None          0.0        29.39     30.12         11.7          7
#
#    AvgSpeed  PrecipCat  NewCodeSum
# 0       9.2  No_Precip           1
# 1       9.6  No_Precip           1
# 2      13.4  No_Precip           0
# 3      13.4  No_Precip           0
# 4      11.9  No_Precip           1

# %%
#Heating degree days are summations of negative differences between the mean daily temperature
#and the 65°F base; cooling degree days are summations of positive differences from the same base.
#For example, cooling degree days for a station with daily mean temperatures during a seven-day 
#period of 67,65,70,74,78,65 and 68, are 2,0,5,9,13,0,and 3, for a total for the week of 32 cooling degree days.

#SO TAVG IS ACTUALLY SAME AS HEAT/COOL? Drop those.

new_cool = []
for i in weather_data['Cool']:
    new_cool.append(65+i)
len(new_cool)
# Out:
# 2944

# %%
weather_data.drop(columns=['Heat','Cool'], axis=1, inplace=True)

# %%
#split weather by stations

station1 = weather_data[weather_data['Station']==1]
print(station1.shape)
station2 = weather_data[weather_data['Station']==2]
print(station2.shape)
# Out:
# (1472, 17)
# (1472, 17)

# %%
station1.head(1)
# Out:
#    Station        Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb CodeSum  \
# 0        1  2007-05-01    83    50    67      14        51       56    None
#
#    PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0          0.0         29.1     29.82          1.7         27       9.2
#
#    PrecipCat  NewCodeSum
# 0  No_Precip           1

# %%
test_data_station1.head(50)
# Out:
#      Id        Date                                            Address  \
# 0     1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1     2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2     3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3     4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4     5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 5     6  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 6     7  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 7     8  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 8     9  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 9    10  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 10   11  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 11   12  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 12   13  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 13   14  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 14   15  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 15   16  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 16   17  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 17   18  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 18   19  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 19   20  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 20   21  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 21   22  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 22   23  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 23   24  2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 24  113  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 25  114  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 26  115  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 27  116  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 28  117  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 29  118  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 30  119  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 31  120  2008-06-11  6500 North Oak Park Avenue, Chicago, IL 60631,...
# 32  121  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 33  122  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 34  123  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 35  124  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 36  125  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 37  126  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 38  127  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 39  128  2008-06-11   7500 North Oakley Avenue, Chicago, IL 60645, USA
# 40  145  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 41  146  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 42  147  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 43  148  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 44  149  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 45  150  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 46  151  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 47  152  2008-06-11   9100 West Higgins Avenue, Chicago, IL 60656, USA
# 48  153  2008-06-11  3600 North Pittsburgh Avenue, Chicago, IL 6063...
# 49  154  2008-06-11  3600 North Pittsburgh Avenue, Chicago, IL 6063...
#
#                    Species  Block             Street  Trap  \
# 0   CULEX PIPIENS/RESTUANS     41     N OAK PARK AVE  T002
# 1           CULEX RESTUANS     41     N OAK PARK AVE  T002
# 2            CULEX PIPIENS     41     N OAK PARK AVE  T002
# 3         CULEX SALINARIUS     41     N OAK PARK AVE  T002
# 4          CULEX TERRITANS     41     N OAK PARK AVE  T002
# 5           CULEX TARSALIS     41     N OAK PARK AVE  T002
# 6        UNSPECIFIED CULEX     41     N OAK PARK AVE  T002
# 7          CULEX ERRATICUS     41     N OAK PARK AVE  T002
# 8   CULEX PIPIENS/RESTUANS     62      N MANDELL AVE  T007
# 9           CULEX RESTUANS     62      N MANDELL AVE  T007
# 10           CULEX PIPIENS     62      N MANDELL AVE  T007
# 11        CULEX SALINARIUS     62      N MANDELL AVE  T007
# 12         CULEX TERRITANS     62      N MANDELL AVE  T007
# 13          CULEX TARSALIS     62      N MANDELL AVE  T007
# 14       UNSPECIFIED CULEX     62      N MANDELL AVE  T007
# 15         CULEX ERRATICUS     62      N MANDELL AVE  T007
# 16  CULEX PIPIENS/RESTUANS     79       W FOSTER AVE  T015
# 17          CULEX RESTUANS     79       W FOSTER AVE  T015
# 18           CULEX PIPIENS     79       W FOSTER AVE  T015
# 19        CULEX SALINARIUS     79       W FOSTER AVE  T015
# 20         CULEX TERRITANS     79       W FOSTER AVE  T015
# 21          CULEX TARSALIS     79       W FOSTER AVE  T015
# 22       UNSPECIFIED CULEX     79       W FOSTER AVE  T015
# 23         CULEX ERRATICUS     79       W FOSTER AVE  T015
# 24  CULEX PIPIENS/RESTUANS     65     N OAK PARK AVE  T143
# 25          CULEX RESTUANS     65     N OAK PARK AVE  T143
# 26           CULEX PIPIENS     65     N OAK PARK AVE  T143
# 27        CULEX SALINARIUS     65     N OAK PARK AVE  T143
# 28         CULEX TERRITANS     65     N OAK PARK AVE  T143
# 29          CULEX TARSALIS     65     N OAK PARK AVE  T143
# 30       UNSPECIFIED CULEX     65     N OAK PARK AVE  T143
# 31         CULEX ERRATICUS     65     N OAK PARK AVE  T143
# 32  CULEX PIPIENS/RESTUANS     75       N OAKLEY AVE  T148
# 33          CULEX RESTUANS     75       N OAKLEY AVE  T148
# 34           CULEX PIPIENS     75       N OAKLEY AVE  T148
# 35        CULEX SALINARIUS     75       N OAKLEY AVE  T148
# 36         CULEX TERRITANS     75       N OAKLEY AVE  T148
# 37          CULEX TARSALIS     75       N OAKLEY AVE  T148
# 38       UNSPECIFIED CULEX     75       N OAKLEY AVE  T148
# 39         CULEX ERRATICUS     75       N OAKLEY AVE  T148
# 40  CULEX PIPIENS/RESTUANS     91      W HIGGINS AVE  T009
# 41          CULEX RESTUANS     91      W HIGGINS AVE  T009
# 42           CULEX PIPIENS     91      W HIGGINS AVE  T009
# 43        CULEX SALINARIUS     91      W HIGGINS AVE  T009
# 44         CULEX TERRITANS     91      W HIGGINS AVE  T009
# 45          CULEX TARSALIS     91      W HIGGINS AVE  T009
# 46       UNSPECIFIED CULEX     91      W HIGGINS AVE  T009
# 47         CULEX ERRATICUS     91      W HIGGINS AVE  T009
# 48  CULEX PIPIENS/RESTUANS     36   N PITTSBURGH AVE  T011
# 49          CULEX RESTUANS     36   N PITTSBURGH AVE  T011
#
#                  AddressNumberAndStreet   Latitude  Longitude  \
# 0     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 1     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 3     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 4     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 5     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 6     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 7     4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 8      6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 9      6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 10     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 11     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 12     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 13     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 14     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 15     6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 16      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 17      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 18      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 19      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 20      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 21      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 22      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 23      7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 24    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 25    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 26    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 27    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 28    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 29    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 30    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 31    6500  N OAK PARK AVE, Chicago, IL  41.999129 -87.795585
# 32      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 33      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 34      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 35      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 36      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 37      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 38      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 39      7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
# 40     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 41     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 42     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 43     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 44     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 45     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 46     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 47     9100  W HIGGINS AVE, Chicago, IL  41.981964 -87.812827
# 48  3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
# 49  3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
#
#     AddressAccuracy  Station
# 0                 9        1
# 1                 9        1
# 2                 9        1
# 3                 9        1
# 4                 9        1
# 5                 9        1
# 6                 9        1
# 7                 9        1
# 8                 9        1
# 9                 9        1
# 10                9        1
# 11                9        1
# 12                9        1
# 13                9        1
# 14                9        1
# 15                9        1
# 16                8        1
# 17                8        1
# 18                8        1
# 19                8        1
# 20                8        1
# 21                8        1
# 22                8        1
# 23                8        1
# 24                8        1
# 25                8        1
# 26                8        1
# 27                8        1
# 28                8        1
# 29                8        1
# 30                8        1
# 31                8        1
# 32                8        1
# 33                8        1
# 34                8        1
# 35                8        1
# 36                8        1
# 37                8        1
# 38                8        1
# 39                8        1
# 40                8        1
# 41                8        1
# 42                8        1
# 43                8        1
# 44                8        1
# 45                8        1
# 46                8        1
# 47                8        1
# 48                8        1
# 49                8        1

# %%
#apply weather data from the stations closest to the data/test sets, merge on 'Date'

train_data_station1 = train_data_station1.merge(station1,on="Date")
train_data_station2 = train_data_station2.merge(station2,on="Date")
test_data_station1 = test_data_station1.merge(station1,on="Date")
test_data_station2 = test_data_station2.merge(station2,on="Date")

# %%
#combining test and train sets that belong to station 1 and 2

train_data = pd.concat([train_data_station1, train_data_station2])
test_data = pd.concat([test_data_station1, test_data_station2])

# %%
train_data.drop(columns=['Station_x','Station_y'], axis=1, inplace=True)
test_data.drop(columns=['Station_x','Station_y'], axis=1, inplace=True)

# %%
#confirming that the number of rows/observations is still the same
train_data.shape, test_data.shape
# Out:
# ((10506, 27), (116293, 26))

# %%
#changing the order back to the original order
test_data = test_data.sort_values(by=['Id'])

# %%
test_data.tail(5)
# Out:
#            Id        Date                                          Address  \
# 80887  116289  2014-10-02  2100 North Cannon Drive, Chicago, IL 60614, USA
# 80888  116290  2014-10-02  2100 North Cannon Drive, Chicago, IL 60614, USA
# 80889  116291  2014-10-02  2100 North Cannon Drive, Chicago, IL 60614, USA
# 80890  116292  2014-10-02  2100 North Cannon Drive, Chicago, IL 60614, USA
# 80891  116293  2014-10-02  2100 North Cannon Drive, Chicago, IL 60614, USA
#
#                  Species  Block        Street   Trap  \
# 80887   CULEX SALINARIUS     21   N CANNON DR  T054C
# 80888    CULEX TERRITANS     21   N CANNON DR  T054C
# 80889     CULEX TARSALIS     21   N CANNON DR  T054C
# 80890  UNSPECIFIED CULEX     21   N CANNON DR  T054C
# 80891    CULEX ERRATICUS     21   N CANNON DR  T054C
#
#                AddressNumberAndStreet   Latitude  Longitude     ...      \
# 80887  2100  N CANNON DR, Chicago, IL  41.925652  -87.63359     ...
# 80888  2100  N CANNON DR, Chicago, IL  41.925652  -87.63359     ...
# 80889  2100  N CANNON DR, Chicago, IL  41.925652  -87.63359     ...
# 80890  2100  N CANNON DR, Chicago, IL  41.925652  -87.63359     ...
# 80891  2100  N CANNON DR, Chicago, IL  41.925652  -87.63359     ...
#
#        WetBulb  CodeSum  PrecipTotal  StnPressure  SeaLevel  ResultSpeed  \
# 80887       65     None         0.72         29.1     29.78          7.2
# 80888       65     None         0.72         29.1     29.78          7.2
# 80889       65     None         0.72         29.1     29.78          7.2
# 80890       65     None         0.72         29.1     29.78          7.2
# 80891       65     None         0.72         29.1     29.78          7.2
#
#        ResultDir AvgSpeed  PrecipCat  NewCodeSum
# 80887         17      7.9      Trace           0
# 80888         17      7.9      Trace           0
# 80889         17      7.9      Trace           0
# 80890         17      7.9      Trace           0
# 80891         17      7.9      Trace           0
#
# [5 rows x 26 columns]

# %%
train_data.to_csv('train_final.csv', index = False)
test_data.to_csv('test_final.csv', index = False)
