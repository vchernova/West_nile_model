# %%
import pandas as pd
import numpy as np

# %%
weather_data = pd.read_csv('./assets/weather.csv')

# %%
weather_data.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# ...

# %%
station1 = weather_data[weather_data['Station']==1]
print(station1.shape)
station2 = weather_data[weather_data['Station']==2]
print(station2.shape)
# Out:
# (1472, 22)
# (1472, 22)

# %%
station1.to_csv('./assets/station1 DAYTIME.csv', index = False)
station2.to_csv('./assets/station2 DAYTIME.csv', index = False)

# %%
df = pd.read_csv('./assets/station1 DAYTIME.csv')

# %%
int(str(df['Sunrise'][3])[2:]) #minute
# Out:
# 4

# %%
int(str(df['Sunrise'][3])[:2]) #hour
# Out:
# 44

# %%
int(str(df['Sunrise'][0])[:-2])*60 + int(str(df['Sunrise'][0])[-2:])
# Out:
# 288

# %%
df['Sunset'].shape
# Out:
# (1472,)

# %%
new_is = []
for i in range (1472):
    new_i = int(str(df['Sunrise'][i])[:-2])*60 + int(str(df['Sunrise'][i])[-2:])
    new_is.append(new_i)
df['Sunrise_min'] = new_is

new_ss = []
for i in range (1472):
    new_i = int(str(df['Sunset'][i])[:-2])*60 + int(str(df['Sunset'][i])[-2:])
    new_ss.append(new_i)
df['Sunset_min'] = new_ss

df['Daytime'] = df['Sunset_min']-df['Sunrise_min']

# %%
df.head(5).T
# Out:
#                       0           1           2           3           4
# Station               1           1           1           1           1
# Date         2007-05-01  2007-05-02  2007-05-03  2007-05-04  2007-05-05
# Tmax                 83          59          66          66          66
# Tmin                 50          42          46          49          53
# Tavg                 67          51          56          58          60
# Depart               14          -3           2           4           5
# DewPoint             51          42          40          41          38
# WetBulb              56          47          48          50          49
# Heat                  0          14           9           7           5
# Cool                  2           0           0           0           0
# Sunrise             448         447         446         444         443
# Sunset             1849        1850        1851        1852        1853
# ...

# %%
df2 = pd.read_csv('./assets/station2 DAYTIME.csv')

# %%
df2['Sunrise'] = df['Sunrise']
df2['Sunset'] = df['Sunset']
df2['Daytime'] = df['Daytime']
df2['Sunrise_min'] = df['Sunrise_min']
df2['Sunset_min'] = df['Sunset_min']

# %%
df2.head().T
# Out:
#                       0           1           2           3           4
# Station               2           2           2           2           2
# Date         2007-05-01  2007-05-02  2007-05-03  2007-05-04  2007-05-05
# Tmax                 84          60          67          78          66
# Tmin                 52          43          48          51          54
# Tavg                 68          52          58           M          60
# Depart                M           M           M           M           M
# DewPoint             51          42          40          42          39
# WetBulb              57          47          50          50          50
# Heat                  0          13           7           M           5
# Cool                  3           0           0           M           0
# Sunrise             448         447         446         444         443
# Sunset             1849        1850        1851        1852        1853
# ...

# %%
df.to_csv('./assets/station1 DAYTIME.csv', index = False)
df2.to_csv('./assets/station2 DAYTIME.csv', index = False)

# %%
weather_data_daytime = pd.concat([df, df2])
weather_data_daytime.to_csv('./assets/weather_data_daytime.csv', index = False)
